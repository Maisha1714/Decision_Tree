# %% [markdown]
# <a href="https://colab.research.google.com/github/Maisha1714/Decision_Tree/blob/main/Decision_Tree_Classifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('/content/shop data.csv')
df.head()
# Out:
#      age  income  gender m_status buys
# 0    <25    high    male   single   no
# 1    <25    high    male  married   no
# 2  25-35    high    male   single  yes
# 3    >35  medium    male   single  yes
# 4    >35     low  female   single  yes

# %%
x = df.iloc[:,:-1]
x
# Out:
#       age  income  gender m_status
# 0     <25    high    male   single
# 1     <25    high    male  married
# 2   25-35    high    male   single
# 3     >35  medium    male   single
# 4     >35     low  female   single
# 5     >35     low  female   single
# 6   25-35     low  female  married
# 7     <25  medium    male  married
# 8     <25     low  female   single
# 9     >35  medium  female  married
# 10    <25  medium  female   single
# 11  25-35  medium    male  married
# 12  25-35    high  female   single
# 13    >35  medium    male  married
# 14    <25    high    male   single
# 15    <25    high  female  married
# 16    >35  medium    male  married
# 17    <25    high  female   single
# 18  25-35  medium  female  married
# 19  25-35    high    male   single
# 20    >35  medium  female  married
# 21    <25     low    male   single

# %%
y = df.iloc[:,4]
y
# Out:
# 0      no
# 1      no
# 2     yes
# 3     yes
# 4     yes
# 5      no
# 6     yes
# 7      no
# 8     yes
# 9     yes
# 10    yes
# 11    yes
# 12    yes
# 13     no
# 14     no
# 15    yes
# 16    yes
# 17    yes
# 18    yes
# 19    yes
# 20     no
# 21    yes
# Name: buys, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_x=LabelEncoder()
x = x.apply(LabelEncoder().fit_transform)

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=.25,random_state=1)
xtrain
# Out:
#     age  income  gender  m_status
# 10    1       2       0         1
# 4     2       1       0         1
# 2     0       0       1         1
# 17    1       0       0         1
# 6     0       1       0         0
# 7     1       2       1         0
# 1     1       0       1         0
# 14    1       0       1         1
# 0     1       0       1         1
# 21    1       1       1         1
# 20    2       2       0         0
# 9     2       2       0         0
# 8     1       1       0         1
# 12    0       0       0         1
# 11    0       2       1         0
# 5     2       1       0         1

# %%
xtest
# Out:
#     age  income  gender  m_status
# 19    0       0       1         1
# 16    2       2       1         0
# 3     2       2       1         1
# 13    2       2       1         0
# 18    0       2       0         0
# 15    1       0       0         0

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dect = DecisionTreeClassifier()

# %%
dect.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
y_predict = dect.predict(xtest)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(ytest,y_predict)
cm
# Out:
# array([[1, 0],
#        [2, 3]])

# %%
xinput = np.array([1,0,0,1])

# %%
y_predict = dect.predict([xinput])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
y_predict
# Out:
# array(['yes'], dtype=object)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
dect.score(xtest,ytest)
# Out:
# 0.6666666666666666
